# %%
student = {
    "name": "Dinesh",
    "age": 20,
    "faculty": "BCE"
}
print(student)
# Out:
# {'name': 'Dinesh', 'age': 20, 'faculty': 'BCE'}

# %%
d = {"name":"Bivhas", "age": 20, "faculty": "BCE"}

# %%
d["name"]
# Out:
# 'Bivhas'

# %%
d["age"]
# Out:
# 20

# %%
d["faculty"]
# Out:
# 'BCE'

# %%
d.get("name")
# Out:
# 'Bivhas'

# %%
d.get("age")
# Out:
# 20

# %%
d.get("faculty")
# Out:
# 'BCE'

# %%
d["name"] = "Dinesh"
print(d)
# Out:
# {'name': 'Dinesh', 'age': 20, 'faculty': 'BCE'}

# %%
d["location"] = "Sitapaila"
print(d)
# Out:
# {'name': 'Dinesh', 'age': 20, 'faculty': 'BCE', 'location': 'Sitapaila'}

# %%
del d["location"]
print(d)
# Out:
# {'name': 'Dinesh', 'age': 20, 'faculty': 'BCE'}

# %%
d.popitem()
print(d)
# Out:
# {'name': 'Dinesh'}

# %%
d.clear()
print(d)
# Out:
# {}

# %%
a = {"name": "Anurodh", "faculty":"BCE", "age": 20}
new_d = a.copy()
print(new_d)
# Out:
# {'name': 'Anurodh', 'faculty': 'BCE', 'age': 20}

# %%
new_d.keys()
# Out:
# dict_keys(['name', 'faculty', 'age'])

# %%
new_d.values()
# Out:
# dict_values(['Anurodh', 'BCE', 20])

# %%
new_d.items()
# Out:
# dict_items([('name', 'Anurodh'), ('faculty', 'BCE'), ('age', 20)])

# %%
"name" in new_d
# Out:
# True

# %%
len(new_d)
# Out:
# 3

# %%
for k in new_d:
    print(k)
# Out:
# name
# faculty
# age

# %%
for v in new_d.values():
    print(v)
# Out:
# Anurodh
# BCE
# 20

# %%
for k,v in new_d.items():
    print(k,v)
# Out:
# name Anurodh
# faculty BCE
# age 20
